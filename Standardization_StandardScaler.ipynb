# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/BS/autompg.csv')

# %% [markdown]
# # StandardScalar

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
X = df.iloc[:, [2, 4]]
y = df.iloc[:, 5]

# %%
X
# Out:
#      displacement  weight
# 0           307.0    3504
# 1           350.0    3693
# 2           318.0    3436
# 3           304.0    3433
# 4           302.0    3449
# ..            ...     ...
# 393         140.0    2790
# 394          97.0    2130
# 395         135.0    2295
# 396         120.0    2625
# 397         119.0    2720
#
# [398 rows x 2 columns]

# %%
y
# Out:
# 0      12.0
# 1      11.5
# 2      11.0
# 3      12.0
# 4      10.5
#        ...
# 393    15.6
# 394    24.6
# 395    11.6
# 396    18.6
# 397    19.4
# Name: acceleration, Length: 398, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 40)

# %%
print(X_train)
# Out:
#      displacement  weight
# 278          89.0    1990
# 0           307.0    3504
# 146          90.0    2125
# 264         302.0    3205
# 290         351.0    4054
# ..            ...     ...
# 306         173.0    2595
# 165         262.0    3221
# 7           440.0    4312
# 219         122.0    2300
# 326          90.0    2335
#
# [318 rows x 2 columns]

# %%
print(y_train)
# Out:
# 278    14.9
# 0      12.0
# 146    14.5
# 264    11.2
# 290    14.3
#        ...
# 306    11.3
# 165    13.5
# 7       8.5
# 219    15.5
# 326    23.7
# Name: acceleration, Length: 318, dtype: float64

# %%
scaler = StandardScaler().fit(X_train)

# %%
scaler
# Out:
# StandardScaler()

# %%
scaled_X_train = scaler.transform(X_train)

# %%
print(scaled_X_train)
# Out:
# [[-1.02128744e+00 -1.18981049e+00]
#  [ 1.09583441e+00  6.28499172e-01]
#  [-1.01157587e+00 -1.02767587e+00]
#  [ 1.04727657e+00  2.69401029e-01]
#  [ 1.52314341e+00  1.28904759e+00]
#  [-9.33883324e-01 -1.02767587e+00]
#  [-8.17344507e-01 -3.70730442e-01]
#  [ 1.20266166e+00  1.68297465e+00]
#  [ 1.51343184e+00  2.06369074e+00]
#  [-1.05042214e+00 -1.20782544e+00]
#  [ 5.66966233e-02 -1.26928024e-01]
#  [-9.33883324e-01 -1.08772573e+00]
#  [ 3.57755235e-01  1.11250102e+00]
#  [-1.02128744e+00 -1.26787530e+00]
#  [ 1.51343184e+00  1.10409404e+00]
#  [-9.43594892e-01 -1.24986034e+00]
#  [ 1.99901025e+00  1.48841312e+00]
#  [ 3.67466803e-01 -1.74967909e-01]
#  [-7.29940394e-01 -5.23257077e-01]
#  [ 2.99485826e-01  3.40259860e-01]
#  [ 2.99485826e-01  5.39625384e-01]
#  [-9.33883324e-01 -1.27988527e+00]
#  [ 5.42275029e-01  4.84175573e-02]
#  [ 5.66966233e-02  2.09351173e-01]
#  [-7.97921371e-01 -7.03406647e-01]
#  [-7.00805690e-01 -8.05491403e-01]
#  [-4.87151191e-01 -3.79137421e-01]
# ...

# %%
scaled_X_train.mean(axis = 0)
# Out:
# array([8.37904170e-17, 3.91021946e-17])

# %%
scaled_X_train.std(axis = 0)
# Out:
# array([1., 1.])

# %%
scale_x_test = StandardScaler().fit(X_test)

# %%
scaled_X_test = scale_x_test.transform(X_test)

# %%
scaled_X_test.mean(axis=0)
# Out:
# array([3.33066907e-17, 1.94289029e-16])

# %%
scaled_X_test.std(axis=0)
# Out:
# array([1., 1.])
